# %% [markdown]
# Step 1: Load the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset='/content/drive/MyDrive/ML/Salary_Dataset.csv'
import pandas as pd
df=pd.read_csv(dataset)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              NaN   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              NaN  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0
# ...

# %%
df.shape
# Out:
# (35, 2)

# %% [markdown]
# **Step 2: Visualization of dataset

# %%
import matplotlib.pyplot as plt
plt.scatter(df.YearsExperience,df['Salary'],marker='*')
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Employee Salary Probability")
plt.grid()
plt.show()

# %%
#########More ways to visualize the things################
#1.USING SEABORN
# #import seaborn as sns
# import pandas as pd

# # Load the dataset
# df = pd.read_csv('dataset.csv')  # Replace 'dataset.csv' with the actual filename or path of your dataset

# # Create a scatter plot using Seaborn
# sns.scatterplot(data=df, x='x', y='y')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.title('Scatter Plot with Seaborn')
# plt.show()


#2.USING PLOTLY
# import plotly.express as px
# import pandas as pd

# # Load the dataset
# df = pd.read_csv('dataset.csv')  # Replace 'dataset.csv' with the actual filename or path of your dataset

# # Create a scatter plot using Plotly
# fig = px.scatter(df, x='x', y='y', title='Scatter Plot with Plotly')
# fig.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

#create a histogram
plt.hist(df['YearsExperience'],bins=10)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Histogram')
plt.show()

# %%
#seaborn lib - heatmaps(To visualize the missing values)
#missingno lib - used to visualize the missing values
import seaborn as sns
import missingno as msno
def get_heatmap(df):
  plt.figure(figsize=(4,2))
  msno.matrix(df)
  sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
  return plt.show
get_heatmap(df)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Step3: Preprocessing the dataset **

# %%
#Treating missing values

'''df.dropna()'''#--->To drop the NaN rows

mean_y=df.YearsExperience.mean()
mean_s=df.Salary.mean()
median_y=df.YearsExperience.median()
median_s=df.Salary.median()

print(mean_y)
print(median_y)
print(mean_s)
print(median_s)
# Out:
# 5.403125
# 4.7
# 76336.03125
# 65237.0

# %%
import math
df['YearsExperience']=df.YearsExperience.fillna(math.floor(df.YearsExperience.mean()))

# %%
df['YearsExperience']
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     5.0
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     5.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# 30     9.0
# 31     4.0
# 32     4.1
# 33     5.0
# 34     9.5
# Name: YearsExperience, dtype: float64

# %%
import math
df['Salary']=df.Salary.fillna(math.floor(df.Salary.mean()))

# %%
df['Salary']
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# 30    105582.0
# 31     76336.0
# 32     57081.0
# 33     76336.0
# 34     76336.0
# Name: Salary, dtype: float64

# %%
#seaborn lib - heatmaps(To visualize the missing values)
#missingno lib - used to visualize the missing values
import seaborn as sns
import missingno as msno
def get_heatmap(df):
  plt.figure(figsize=(4,2))
  msno.matrix(df)
  sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
  return plt.show
get_heatmap(df)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
plt.scatter(df.YearsExperience,df['Salary'],marker='*')
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Employee Salary Probability")
plt.grid()
plt.show()

# %%
df['YearsExperience']
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     5.0
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     5.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# 30     9.0
# 31     4.0
# 32     4.1
# 33     5.0
# 34     9.5
# Name: YearsExperience, dtype: float64

# %%
# looking whether linear regression is uitable for above data

import pandas as pd
from scipy import stats

import numpy as np
x=np.array(df['YearsExperience'])
x
y=np.array(df['Salary'])
y

# #df=pd.DataFrame({'YearsExperience','Salary'})
# x=df['YearsExperience'].values
# y=df['Salary'].values
print(type(x))

# slope,intercept,r_value,p_value,std_err=stats.linregress(x,y)
# r=r_value
# print(r)

print(x)
print(y)
# Out:
# <class 'numpy.ndarray'>
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   5.
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  5.   9.5  9.6
#  10.3 10.5  9.   4.   4.1  5.   9.5]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872. 105582.  76336.  57081.  76336.  76336.]

# %%
#Checking for r
import numpy as np
from scipy import stats

x = np.array([1.1, 1.3, 1.5, 2.0, 2.2, 2.9, 3.0, 3.2, 3.2, 3.7, 3.9, 4.0, 4.0, 5.0, 4.5, 4.9, 5.1, 5.3, 5.9, 6.0, 6.8, 7.1, 7.9, 8.2, 8.7, 5.0, 9.5, 9.6, 10.3, 10.5, 9.0, 4.0, 4.1, 5.0, 9.5])
y = np.array([39343.0, 46205.0, 37731.0, 43525.0, 39891.0, 56642.0, 60150.0, 54445.0, 64445.0, 57189.0, 63218.0, 55794.0, 56957.0, 57081.0, 61111.0, 67938.0, 66029.0, 83088.0, 81363.0, 93940.0, 91738.0, 98273.0, 101302.0, 113812.0, 109431.0, 105582.0, 116969.0, 112635.0, 122391.0, 121872.0, 105582.0, 76336.0, 57081.0, 76336.0, 76336.0])

slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
r = r_value
print("Relationship coefficient (r):", r)
# Out:
# Relationship coefficient (r): 0.9131703297877996

# %% [markdown]
# Step 4: Loading the data

# %%
X=df.iloc[:,0:1]

Y=df.iloc[:,1:2]

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              5.0
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              5.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5
# 30              9.0
# 31              4.0
# 32              4.1
# 33              5.0
# 34              9.5

# %%
Y
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0
# 30  105582.0
# 31   76336.0
# 32   57081.0
# 33   76336.0
# 34   76336.0

# %%
X=df.iloc[:,:-1].values
print(X)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 5. ]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 5. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]
#  [ 9. ]
#  [ 4. ]
#  [ 4.1]
#  [ 5. ]
#  [ 9.5]]

# %%
Y=df.iloc[:,-1:].values
print(Y)
# Out:
# [[ 39343.]
#  [ 46205.]
#  [ 37731.]
#  [ 43525.]
#  [ 39891.]
#  [ 56642.]
#  [ 60150.]
#  [ 54445.]
#  [ 64445.]
#  [ 57189.]
#  [ 63218.]
#  [ 55794.]
#  [ 56957.]
#  [ 57081.]
#  [ 61111.]
#  [ 67938.]
#  [ 66029.]
#  [ 83088.]
#  [ 81363.]
#  [ 93940.]
#  [ 91738.]
#  [ 98273.]
#  [101302.]
#  [113812.]
#  [109431.]
#  [105582.]
#  [116969.]
#  [112635.]
#  [122391.]
#  [121872.]
#  [105582.]
#  [ 76336.]
#  [ 57081.]
#  [ 76336.]
#  [ 76336.]]

# %% [markdown]
# Step 5: Splitting the dataset - Train Set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train
# Out:
# array([[ 1.3],
#        [ 8.2],
#        [ 4.9],
#        [ 2.9],
#        [ 1.1],
#        [ 6. ],
#        [ 1.5],
#        [ 4. ],
#        [ 9.6],
#        [ 8.7],
#        [ 7.1],
#        [ 4. ],
#        [ 4. ],
#        [ 3.9],
#        [ 2. ],
#        [ 4.1],
#        [ 3.7],
#        [ 5. ],
#        [10.5],
#        [ 5.1],
#        [ 3. ],
#        [ 5.9],
#        [ 9.5],
#        [ 7.9]])

# %%
Y_train
# Out:
# array([[ 46205.],
#        [113812.],
#        [ 67938.],
#        [ 56642.],
#        [ 39343.],
#        [ 93940.],
#        [ 37731.],
#        [ 55794.],
#        [112635.],
#        [109431.],
#        [ 98273.],
#        [ 76336.],
#        [ 56957.],
#        [ 63218.],
#        [ 43525.],
#        [ 57081.],
#        [ 57189.],
#        [ 76336.],
#        [121872.],
#        [ 66029.],
#        [ 60150.],
#        [ 81363.],
#        [116969.],
#        [101302.]])

# %%
X_test
# Out:
# array([[ 9.5],
#        [10.3],
#        [ 9. ],
#        [ 5.3],
#        [ 4.5],
#        [ 5. ],
#        [ 6.8],
#        [ 5. ],
#        [ 3.2],
#        [ 3.2],
#        [ 2.2]])

# %%
Y_test
# Out:
# array([[ 76336.],
#        [122391.],
#        [105582.],
#        [ 83088.],
#        [ 61111.],
#        [105582.],
#        [ 91738.],
#        [ 57081.],
#        [ 64445.],
#        [ 54445.],
#        [ 39891.]])

# %% [markdown]
# Step 6: Train the model - Feeding the mdoel /Fitting the loop

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
import pandas as pd
columns=['YearExperience','Salary']
df=pd.DataFrame(zip(X_train,Y_train),columns=columns)
print(df)
# Out:
#    YearExperience      Salary
# 0           [1.3]   [46205.0]
# 1           [8.2]  [113812.0]
# 2           [4.9]   [67938.0]
# 3           [2.9]   [56642.0]
# 4           [1.1]   [39343.0]
# 5           [6.0]   [93940.0]
# 6           [1.5]   [37731.0]
# 7           [4.0]   [55794.0]
# 8           [9.6]  [112635.0]
# 9           [8.7]  [109431.0]
# 10          [7.1]   [98273.0]
# 11          [4.0]   [76336.0]
# 12          [4.0]   [56957.0]
# 13          [3.9]   [63218.0]
# 14          [2.0]   [43525.0]
# 15          [4.1]   [57081.0]
# 16          [3.7]   [57189.0]
# 17          [5.0]   [76336.0]
# 18         [10.5]  [121872.0]
# 19          [5.1]   [66029.0]
# 20          [3.0]   [60150.0]
# 21          [5.9]   [81363.0]
# 22          [9.5]  [116969.0]
# 23          [7.9]  [101302.0]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
import sympy as sym

# %%
df['YearExperience']
# Out:
# 0      [1.3]
# 1      [8.2]
# 2      [4.9]
# 3      [2.9]
# 4      [1.1]
# 5      [6.0]
# 6      [1.5]
# 7      [4.0]
# 8      [9.6]
# 9      [8.7]
# 10     [7.1]
# 11     [4.0]
# 12     [4.0]
# 13     [3.9]
# 14     [2.0]
# 15     [4.1]
# 16     [3.7]
# 17     [5.0]
# 18    [10.5]
# 19     [5.1]
# 20     [3.0]
# 21     [5.9]
# 22     [9.5]
# 23     [7.9]
# Name: YearExperience, dtype: object

# %%
for sample in range(len(X_train)):
    xa = X_train[sample,0]
    # Do something with xa
    print(xa)
# Out:
# 2.2
# 1.5
# 1.3
# 5.0
# 10.3
# 3.7
# 6.8
# 9.6
# 5.9
# 5.1
# 4.1
# 6.0
# 4.9
# 3.0
# 9.0
# 4.0
# 10.5
# 5.3
# 9.5
# 7.1
# 8.2
# 2.0
# 1.1
# 3.2

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
import numpy as np
mi=1
ci=-1
n=0.01
epochs=10
MSE=[]

for iter in range(1,epochs+1):
  print("ITER:{}".format(iter))
  print("########################")

  for sample in range(0,len(X_train)):
    #xa=X_train['YearsExperience'].iloc[sample]
    xa=X_train[sample,0]
    ya=Y_train[sample,0]
    print("--->Sample {}".format(sample+1)+"x={}".format(xa)+"y={}".format(ya))

    #step 4:Compute Gradient (to know how error rate is affected w.r.t m,c)
    x=sym.Symbol('x')
    y=sym.Symbol('y')
    c=sym.Symbol('c')
    m=sym.Symbol('m')
    E=(0.5)*(y-m*x-c)**2 # Half mean square equation

    #so as to substitute values into the equation we need to explicitly tell python control that the variables are symbols
    #diff-->used for derivation
    deltaE_m=sym.diff(E,m)
    deltaE_c=sym.diff(E,c)
    print(deltaE_m)
    print(deltaE_c)

    #substitute the values in deltaE_m
    deltaE_m=deltaE_m.subs(m,mi)
    deltaE_m=deltaE_m.subs(c,ci)
    deltaE_m=deltaE_m.subs(x,xa)
    deltaE_m=deltaE_m.subs(y,ya)

    #substitute the values in deltaE_c
    deltaE_c=deltaE_c.subs(m,mi)
    deltaE_c=deltaE_c.subs(c,ci)
    deltaE_c=deltaE_c.subs(x,xa)
    deltaE_c=deltaE_c.subs(y,ya)

    print("Obtained Gradient w.rt. m an c")
    print("deltaE_m",deltaE_m)
    print("deltaE_c",deltaE_c)

    #step 5:Calculate step length- change
    del_m= -n*deltaE_m
    del_c= -n*deltaE_c

    #step 6: updating the model param
    mi=mi+del_m
    ci=ci+del_c



    print("m:{}".format(mi),"c:{}".format(ci))


  E=E.subs(m,mi)
  E=E.subs(c,ci)
  E=E.subs(x,xa)
  E=E.subs(y,ya)
  print("Error:",E)
  MSE.append(E)
  print(MSE)
  # for i in str(E):
  #   MSE.append(i)
  # print(MSE)
  print("---------------------------------------")
print("optimal Params:")
print("m={}".format(mi))
print("c={}".format(ci))
# Out:
# ITER:1
# ########################
# --->Sample 1x=2.2y=39891.0
# -1.0*x*(-c - m*x + y)
# 1.0*c + 1.0*m*x - 1.0*y
# Obtained Gradient w.rt. m an c
# deltaE_m -87757.5600000000
# deltaE_c -39889.8000000000
# m:878.575600000000 c:397.898000000000
# --->Sample 2x=1.5y=37731.0
# -1.0*x*(-c - m*x + y)
# 1.0*c + 1.0*m*x - 1.0*y
# Obtained Gradient w.rt. m an c
# deltaE_m -54022.8579000000
# deltaE_c -36015.2386000000
# m:1418.80417900000 c:758.050386000000
# --->Sample 3x=1.3y=46205.0
# -1.0*x*(-c - m*x + y)
# 1.0*c + 1.0*m*x - 1.0*y
# Obtained Gradient w.rt. m an c
# deltaE_m -56683.2554356900
# deltaE_c -43602.5041813000
# m:1985.63673335690 c:1194.07542781300
# --->Sample 4x=5.0y=57081.0
# -1.0*x*(-c - m*x + y)
# 1.0*c + 1.0*m*x - 1.0*y
# Obtained Gradient w.rt. m an c
# deltaE_m -229793.704527012
# deltaE_c -45958.7409054025
# m:4283.57377862703 c:1653.66283686702
# --->Sample 5x=10.3y=122391.0
# -1.0*x*(-c - m*x + y)
# 1.0*c + 1.0*m*x - 1.0*y
# Obtained Gradient w.rt. m an c
# ...

# %%
MSE
# Out:
# [30376041.7936262,
#  26131756.0841543,
#  22407584.3556448,
#  19145348.2828765,
#  16293135.9096902,
#  13804629.6640585,
#  11638515.2197777,
#  9757952.22027396,
#  8130100.42209170,
#  6725695.48490473]

# %%
import matplotlib.pyplot as plt
plt.plot(MSE,label='MSE',color='red')
plt.xlabel("YOE")
plt.ylabel("Salary")
plt.legend()
plt.title("YOE vs Salary")
plt.show()

# %%
mi
# Out:
# 12005.7037919245

# %%
ci
# Out:
# 12359.1340680420

# %%
YOE= int(input("enter year of experienxe"))
sme= mi*YOE+ci
sme
# Out:
# enter year of experienxe4
# 60381.9492357401

# %%
y_pred= mi*X+ci
#plotting for data
plt.scatter(X,Y)
plt.plot(X,y_pred)
#here X=X_test and Y=Y_test

# %%
df
# Out:
#            0
# 0    46205.0
# 1   113812.0
# 2    67938.0
# 3    56642.0
# 4    39343.0
# 5    93940.0
# 6    37731.0
# 7    55794.0
# 8   112635.0
# 9   109431.0
# 10   98273.0
# 11   76336.0
# 12   56957.0
# 13   63218.0
# 14   43525.0
# 15   57081.0
# 16   57189.0
# 17   76336.0
# 18  121872.0
# 19   66029.0
# 20   60150.0
# 21   81363.0
# 22  116969.0
# 23  101302.0

# %% [markdown]
# Step 7: Testing the model

# %%
Y_pred= model.predict(X_test)
Y_pred
# Out:
# array([[ 71038.93456918],
#        [109071.570029  ],
#        [117523.26679785],
#        [102310.21261392],
#        [ 95548.85519884],
#        [ 70193.76489229],
#        [ 55825.88038525],
#        [ 73574.44359983],
#        [ 61742.06812345],
#        [ 55825.88038525],
#        [104845.72164457]])

# %% [markdown]
# Step 8: Performance Evaluation

# %%
model.score(X_test,Y_test)*100
# Out:
# 74.02739100867343

# %%
model.score(X_train,Y_train)*100
# Out:
# 82.28016484350935

# %%
model.score(X,Y)*100
# Out:
# 82.59009896960427

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(Y_test,Y_pred)
# Out:
# 0.08085101687111114

# %%
import matplotlib.pyplot as plt
plt.scatter(df.YearsExperience,df['Salary'],marker='*')
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Employee Salary Probability")
plt.grid()
plt.show()

# %% [markdown]
# Visualize The Result

# %%
model.coef_
# Out:
# array([[8451.69676885]])

# %%
model.intercept_
# Out:
# array([28780.45072494])

# %%
#y=(8451.6)x+28780.45

# %%
y_pred= model.coef_*X+model.intercept_
#plotting for data
plt.scatter(X,Y)
plt.plot(X,y_pred)
#here X=X_test and Y=Y_test

# %% [markdown]
# Traing Set- Evaluation

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,model.predict(X_train),color='blue')
plt.show()

# %% [markdown]
# Test Set- Evaluation

# %%
import matplotlib.pyplot as plt
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test,model.predict(X_test),color='blue')
plt.show()

# %%
YearExperience= int(input("enter year of experienxe"))
y_pred= model.coef_*YearExperience+model.intercept_
y_pred
# Out:
# enter year of experienxe4
# array([[62587.23780033]])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c9763c9cf176> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.DataFrame(X_train)
#       3 df=pd.DataFrame(Y_train)
#       4 print(df)
#
# NameError: name 'X_train' is not defined
