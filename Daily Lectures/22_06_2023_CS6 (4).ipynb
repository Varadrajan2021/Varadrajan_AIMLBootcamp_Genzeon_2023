# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset='/content/drive/MyDrive/ML/Crop_recommendation.csv'
import pandas as pd
df=pd.read_csv(dataset)

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
print(df.isna().sum())
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
#####SKIP#####
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df_sample=df

# Extract the target column as a separate series
target = df_sample['label']

# Create an instance of LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder on the target column and transform the labels
encoded_target = label_encoder.fit_transform(target)

# Update the target column in the DataFrame with the encoded labels
df_sample['target_column_encoded'] = encoded_target

# Print the updated DataFrame
print(df_sample)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label  \
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
#       target_column_encoded
# 0                        20
# 1                        20
# ...

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
#Understanding the distribution
import seaborn as sns
with sns.plotting_context("notebook"):
  sns.pairplot(df[['N','P','K','temperature','humidity','ph','rainfall','target_column_encoded']],hue='target_column_encoded',palette='tab20')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
columns=['N','P','K','temperature','humidity','ph','rainfall','target_column_encoded']
data=df[columns]
col_mat=data.corr()
sns.heatmap(col_mat,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import seaborn as sns

import matplotlib.pyplot as plt




plt.figure(figsize=(15, 28))

plt.subplot(4, 2, 1)

sns.barplot(x='N', y='label', data=df)

plt.xlabel('N')

plt.ylabel('Crops')

plt.title('Bar Plot of N vs Crops')

plt.show()






plt.figure(figsize=(15, 28))

plt.subplot(4, 2, 2)

sns.barplot(x='P', y='label', data=df)

plt.xlabel('P')

plt.ylabel('Crops')

plt.title('Bar Plot of P vs Crops')

plt.show()




plt.figure(figsize=(15, 28))

plt.subplot(4, 2, 3)

sns.barplot(x='K', y='label', data=df)

plt.xlabel('K')

plt.ylabel('Crops')

plt.title('Bar Plot of K vs Crops')

plt.show()




plt.figure(figsize=(15, 28))

plt.subplot(4, 2, 4)

sns.barplot(x='temperature', y='label', data=df)

plt.xlabel('temp')

plt.ylabel('Crops')

plt.title('Bar Plot of temp vs Crops')

plt.show()




plt.figure(figsize=(15, 28))

plt.subplot(4, 2, 5)

sns.barplot(x='humidity', y='label', data=df)

plt.xlabel('humidity')

plt.ylabel('Crops')

plt.title('Bar Plot of humidity vs Crops')

plt.show()




plt.figure(figsize=(15, 28))

plt.subplot(4, 2, 6)

sns.barplot(x='ph', y='label', data=df)

plt.xlabel('ph')

plt.ylabel('Crops')

plt.title('Bar Plot of ph vs Crops')

plt.show()




plt.figure(figsize=(15, 28))

plt.subplot(4, 2, 7)

sns.barplot(x='rainfall', y='label', data=df)

plt.xlabel('Rf')

plt.ylabel('Crops')

plt.title('Bar Plot of Rf vs Crops')

plt.show()

# %%
target_column_encoded_corelations = col_mat["target_column_encoded"]
tar_col_en_sorted=target_column_encoded_corelations.sort_values(ascending=False)
print(tar_col_en_sorted)
# Out:
# target_column_encoded    1.000000
# humidity                 0.193911
# temperature              0.113606
# rainfall                 0.045611
# ph                      -0.012253
# N                       -0.031130
# K                       -0.346417
# P                       -0.491006
# Name: target_column_encoded, dtype: float64

# %%
X=df.drop('label',axis=1)
Y=df['label']

# %%
X
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
Y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
#splitting
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train

# %%
from sklearn.preprocessing  import StandardScaler
sc=StandardScaler()
X_train =sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
Y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test,Y_pred)
print(acc)
# Out:
# 0.9931818181818182

# %% [markdown]
# **SVM**

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(X_train, Y_train)
Y_pred = svm.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9772727272727273

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(X_train, Y_train)
Y_pred = svm.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.990909090909091

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.975

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9863636363636363

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9545454545454546
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9727272727272728

# %%
N=int(input("Enter value for N : "))

P=int(input("Enter value for P : "))

K=int(input("Enter value for K : "))

temperature=float(input("Enter value for temperature : "))

humidity=float(input("Enter value for humidity : "))

ph=float(input("Enter value for ph : "))

rainfall=float(input("Enter value for rainfall : "))




new_data=[[N,P,K,temperature,humidity,ph,rainfall]]




prediction=model.predict(new_data)
cat_pred=cnb.predict(new_data)
svm_pred=svm.predict(new_data)
knn_pred=knn.predict(new_data)
logreg_pred=logreg.predict(new_data)

print(prediction[0])
print(cat_pred[0])
print(svm_pred[0])
print(knn_pred[0])
print(logreg_pred[0])
# Out:
# Enter value for N : 90
# Enter value for P : 42
# Enter value for K : 43
# Enter value for temperature : 20.8
# Enter value for humidity : 82
# Enter value for ph : 6.5
# Enter value for rainfall : 203
# rice
# rice
# rice
# rice
# rice
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# **Grad IO**

# %%
# !pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 50.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.4/288.4 kB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# N P K temperature humidity  ph  rainfall




import gradio as gr

def predict(N, P, K, temperature, humidity, ph, rainfall):

    # Process the inputs if necessary

    # Run your prediction model with the provided inputs

    # Return the prediction result

    new_data=[[N,P,K,temperature,humidity,ph,rainfall]]


    prediction=knn.predict(new_data)

    # Example: Returning a static prediction for demonstration purposes

    return prediction[0] # Replace "Wheat" with your actual prediction

# Create Gradio inputs

inputs = [

    gr.inputs.Number(label="N"),

    gr.inputs.Number(label="P"),

    gr.inputs.Number(label="K"),

    gr.inputs.Number(label="Temperature"),

    gr.inputs.Number(label="Humidity"),

    gr.inputs.Number(label="pH"),

    gr.inputs.Number(label="Rainfall"),

]




demo = gr.Interface(fn=predict, inputs=inputs, outputs="text")



if __name__ == "__main__":

    demo.launch()
# Out:
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:59: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:62: UserWarning: `optional` parameter is deprecated, and it has no effect
#   super().__init__(value=default, label=label, optional=optional)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
